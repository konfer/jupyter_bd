# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samples=np.random.normal(size=(100))

# %%
samples
# Out:
# array([-0.13994674, -0.65846969,  1.27715419,  0.19784195,  0.39110076,
#        -0.83473212, -0.62650906, -1.27921951, -0.36660778, -0.68760097,
#        -0.77618217, -0.2723768 , -0.04220077,  1.54669525,  0.82234456,
#        -0.25394533, -0.69239969, -1.19409001, -0.92514678, -0.73886766,
#        -1.48857368,  0.59883142,  0.44380844,  0.65611568,  0.36297989,
#        -0.32335186, -1.49673293, -1.33318849,  0.82091317, -0.16754921,
#        -1.75243898,  0.01849046,  1.0694751 , -0.1443809 ,  0.66901296,
#        -0.82247138,  1.4066746 , -1.21889351,  1.80334048,  1.1217168 ,
#         0.54830427,  0.14493073,  0.37553687,  1.14847173,  1.04215382,
#         1.24248444,  0.22097795,  0.34637753, -0.40860428, -0.64196077,
#        -0.12804457,  0.22777769,  1.06617161, -0.04373869,  0.11621913,
#        -1.4430722 ,  1.23801356,  1.69848866, -0.41625116, -0.82507118,
#        -0.40932369, -0.35180133,  1.78989655,  1.04832508,  0.8528239 ,
# ...

# %%
% matplotlib inline
plt.hist(samples,bins=50)
# Out:
# (array([1., 0., 0., 1., 1., 0., 1., 2., 1., 1., 3., 2., 2., 1., 1., 5., 3.,
#         4., 2., 3., 4., 4., 4., 1., 3., 3., 1., 5., 5., 0., 4., 2., 1., 1.,
#         2., 4., 3., 1., 1., 4., 2., 3., 1., 1., 0., 2., 0., 1., 2., 1.]),
#  array([-2.10845717, -2.02752692, -1.94659668, -1.86566643, -1.78473619,
#         -1.70380594, -1.6228757 , -1.54194545, -1.46101521, -1.38008496,
#         -1.29915471, -1.21822447, -1.13729422, -1.05636398, -0.97543373,
#         -0.89450349, -0.81357324, -0.732643  , -0.65171275, -0.5707825 ,
#         -0.48985226, -0.40892201, -0.32799177, -0.24706152, -0.16613128,
#         -0.08520103, -0.00427079,  0.07665946,  0.15758971,  0.23851995,
#          0.3194502 ,  0.40038044,  0.48131069,  0.56224093,  0.64317118,
#          0.72410142,  0.80503167,  0.88596191,  0.96689216,  1.04782241,
#          1.12875265,  1.2096829 ,  1.29061314,  1.37154339,  1.45247363,
#          1.53340388,  1.61433412,  1.69526437,  1.77619462,  1.85712486,
# ...

# %%
a=np.random.rand()

# %%
b=np.random.rand(4)

# %%
c=np.random.rand(2,3)

# %%
samplesOne=np.random.rand(1000)
samplesTwo=np.random.rand(1000)
plt.scatter(samplesOne,samplesTwo)

# %%
samplesOne=np.random.randn(1000)
samplesTwo=np.random.randn(1000)
plt.scatter(samplesOne,samplesTwo)

# %%
print(np.random.randint(2))
# Out:
# 1

# %%
print(np.random.randint(69,size=5))
# Out:
# [19  0 34 28  7]

# %%
print(np.random.randint(2,7,size=3))
# Out:
# [3 5 6]

# %%
print(np.random.randint(2,size=(2,3)))
# Out:
# [[1 1 1]
#  [0 0 0]]

# %%
print(np.random.randint(2,19,(4,3)))
# Out:
# [[ 4  3  9]
#  [ 9  6 10]
#  [16  7  7]
#  [ 4  9 18]]

# %%
rng=np.random.RandomState(1)

# %%
xtrain=10*rng.rand(30)

# %%
ytrain=8+4*xtrain+rng.rand(30)*2

# %%
fig=plt.figure(figsize=(12,3))

# %%
ax1=fig.add_subplot(1,2,1)

# %%
plt.scatter(xtrain,ytrain,marker='.',color='k')
plt.grid()
plt.title("scatter grid")
# Out:
# Text(0.5,1,'scatter grid')
