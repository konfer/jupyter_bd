# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread('image.jpg')

# %%
image
# Out:
# array([[[ 29,  32,  46],
#         [ 30,  33,  47],
#         [ 30,  33,  47],
#         ...,
#         [ 17,  11,  12],
#         [ 16,  10,  11],
#         [ 14,   8,   9]],
#
#        [[ 25,  28,  42],
#         [ 26,  29,  43],
#         [ 27,  30,  44],
#         ...,
#         [ 16,  10,  11],
#         [ 15,   9,  10],
#         [ 14,   8,   9]],
#
#        [[ 22,  25,  39],
#         [ 23,  26,  40],
#         [ 24,  27,  41],
#         ...,
#         [ 15,   9,  10],
#         [ 13,   7,   8],
#         [ 12,   6,   7]],
#
#        ...,
#
#        [[ 15,  26,  30],
#         [ 20,  31,  35],
#         [ 24,  37,  39],
#         ...,
#         [169, 254, 255],
#         [171, 253, 255],
#         [171, 254, 255]],
#
#        [[ 17,  28,  32],
#         [ 22,  33,  37],
#         [ 25,  37,  41],
#         ...,
#         [172, 253, 255],
#         [174, 252, 255],
#         [174, 252, 255]],
#
#        [[ 20,  31,  35],
#         [ 24,  35,  39],
#         [ 26,  38,  42],
#         ...,
#         [172, 252, 255],
#         [176, 251, 255],
#         [176, 251, 255]]], dtype=uint8)

# %%
print("width: %d pixels" % (image.shape[1]))
# Out:
# width: 1080 pixels

# %%
print("height: %d pixels" % (image.shape[0]))
# Out:
# height: 1440 pixels

# %%
print("channels: %d pixels" % (image.shape[2]))
# Out:
# channels: 3 pixels

# %%
image.shape
# Out:
# (1440, 1080, 3)

# %%
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
imageBGR=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
imageBGR
# Out:
# array([[[ 46,  32,  29],
#         [ 47,  33,  30],
#         [ 47,  33,  30],
#         ...,
#         [ 12,  11,  17],
#         [ 11,  10,  16],
#         [  9,   8,  14]],
#
#        [[ 42,  28,  25],
#         [ 43,  29,  26],
#         [ 44,  30,  27],
#         ...,
#         [ 11,  10,  16],
#         [ 10,   9,  15],
#         [  9,   8,  14]],
#
#        [[ 39,  25,  22],
#         [ 40,  26,  23],
#         [ 41,  27,  24],
#         ...,
#         [ 10,   9,  15],
#         [  8,   7,  13],
#         [  7,   6,  12]],
#
#        ...,
#
#        [[ 30,  26,  15],
#         [ 35,  31,  20],
#         [ 39,  37,  24],
#         ...,
#         [255, 254, 169],
#         [255, 253, 171],
#         [255, 254, 171]],
#
#        [[ 32,  28,  17],
#         [ 37,  33,  22],
#         [ 41,  37,  25],
#         ...,
#         [255, 253, 172],
#         [255, 252, 174],
#         [255, 252, 174]],
#
#        [[ 35,  31,  20],
#         [ 39,  35,  24],
#         [ 42,  38,  26],
#         ...,
#         [255, 252, 172],
#         [255, 251, 176],
#         [255, 251, 176]]], dtype=uint8)

# %%
plt.imshow(imageBGR)
plt.show()
