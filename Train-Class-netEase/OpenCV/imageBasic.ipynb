# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread('image.jpg')

# %%
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
(h,w,c)=image.shape

# %%
print(image.shape)
# Out:
# (1440, 1080, 3)

# %%
h
# Out:
# 1440

# %%
w
# Out:
# 1080

# %%
c
# Out:
# 3

# %%
(firstB,firstG,firstR)=image[0,0]

# %%
centreX,centreY=(h//2,w//2)
t1=image[0:centreX,0:centreY]
plt.imshow(t1)
plt.axis("off")
plt.show()
