# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.rand(10))
plt.show()

# %%
% matplotlib inline
x=np.random.randn(100)
y=np.random.randn(100)
plt.scatter(x,y)
plt.show()

# %%
# %matplotlib notebook
s=pd.Series(np.random.randn(100))
s.plot(style='k--o',figsize=(10,5))
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
s
# Out:
# 0    -0.104070
# 1    -1.395049
# 2     0.911024
# 3    -0.326770
# 4    -0.204212
# 5     2.104925
# 6     0.714709
# 7    -0.737468
# 8     0.299183
# 9    -0.138275
# 10   -1.324072
# 11    1.470315
# 12    0.113901
# 13    0.131350
# 14   -0.990623
# 15   -1.127569
# 16    0.300967
# 17   -1.494839
# 18   -0.600151
# 19   -0.128483
# 20   -1.727340
# 21   -1.600489
# 22   -0.253713
# 23   -0.422670
# 24   -0.702080
# 25   -1.530608
# 26   -1.326932
# 27   -0.515548
# 28   -0.417378
# 29    1.275314
#         ...
# 70    0.818826
# 71   -0.386502
# 72   -2.281630
# 73    0.282829
# 74   -0.060033
# 75   -0.985523
# 76    1.415348
# 77    0.940530
# 78    1.347396
# 79   -0.821486
# 80   -0.485899
# 81   -0.126604
# 82    0.166723
# 83    1.869773
# 84   -0.293117
# 85    1.697015
# 86    0.516857
# 87    0.170234
# 88    0.340148
# 89    1.605251
# 90   -0.914701
# 91   -1.199135
# 92    0.528716
# 93    1.411248
# 94    0.598109
# 95   -0.120215
# 96    0.565184
# 97   -0.076849
# 98   -0.904548
# 99   -0.068016
# Length: 100, dtype: float64

# %%
# %matplotlib qt5
df=pd.DataFrame(np.random.rand(50,2),columns=['A','B'])
df.hist(figsize=(12,5),color='g',alpha=0.8)
# Out:
# Warning: Cannot change to a different GUI toolkit: qt5. Using notebook instead.
# <img src="data:image/png;base64,..." width="864">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8471e08cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8471e1d240>]],
#       dtype=object)
