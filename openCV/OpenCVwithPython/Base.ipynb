# %%
from PIL import Image

# %%
import os

# %%
pil_im=Image.open('data/empire.jpg')

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=569x800 at 0x7FD609649B38>

# %%
pil_im_ConvertL=Image.open('data/empire.jpg').convert('L')

# %%
pil_im_ConvertL
# Out:
# <PIL.Image.Image image mode=L size=569x800 at 0x7FD6081A12E8>

# %%
pil_im_ConvertL.thumbnail((128,128))

# %%
pil_im_ConvertL
# Out:
# <PIL.Image.Image image mode=L size=91x128 at 0x7FD6081A12E8>

# %%
box=(100,100,400,400)

# %%
region=pil_im.crop(box)

# %%
region=region.transpose(Image.ROTATE_180)

# %%
pil_im.paste(region,box)

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=569x800 at 0x7FD609649B38>

# %%
out=pil_im.resize((128,128))

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD5F1E6F1D0>

# %%
rotateOut=pil_im.rotate(45)

# %%
rotateOut
# Out:
# <PIL.Image.Image image mode=RGB size=569x800 at 0x7FD5F1EE2048>
